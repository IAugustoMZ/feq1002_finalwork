# %% [markdown]
# # Modeling Saturation Properties of Ammonia
#
# <br>
#
# This notebook aims to create regression models to predict saturation properties of ammonia, based on experimental data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib
import warnings
import sys
sys.path.append('../modules/')
from utils_functions import utils
from validation import validate
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

############################################# IMPORTANT DEFINITIONS ###########################################################
RANDOM_SEED = 1002
warnings.filterwarnings('ignore')
SATURATION_DATA_FILEPATH = '../data'
SATURATION_FILENAME = 'SaturationProperties.xlsx'
FLUID_CODE = 2 # ammonia
compound = 'ammonia'
basic = utils()
validation = validate()

# %% [markdown]
# ## 1. Vapor Pressure

# %%
# import data
data = basic.load_filter_data(vapor_fraction = 0, 
                              fluid_code = FLUID_CODE, 
                              complete_filepath = os.path.join(SATURATION_DATA_FILEPATH, SATURATION_FILENAME))
data.head()
# Out:
#        t         p  x         v         h         s
# 0  195.5  0.006091  0  0.023237  0.000142  0.000000
# 1  200.0  0.008651  0  0.023389  0.323530  0.001635
# 2  210.0  0.017739  0  0.023747  1.048400  0.005171
# 3  220.0  0.033790  0  0.024130  1.783300  0.008587
# 4  230.0  0.060407  0  0.024541  2.527900  0.011894

# %% [markdown]
# ### 1.1 Vapor Pressure Model Validation

# %%
validation.vapor_pressure(data, FLUID_CODE)
# Out:
# [INFO] Mean Absolute Error: 0.0005
# [INFO] Root Mean Squared Error: 0.0212
# [INFO] R2 Score: 1.0000

# %% [markdown]
# ### 1.2. Saturation Temperature Model Validation

# %%
validation.sat_temperature(data, FLUID_CODE)
# Out:
# [INFO] Mean Absolute Error: 0.0209
# [INFO] Root Mean Squared Error: 0.1446
# [INFO] R2 Score: 1.0000

# %% [markdown]
# ## 2. Saturated Liquid Specific Volume

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['v']]

# %%
# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_volume')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_volume')
# Out:
# Text(0, 0.5, 'specific_volume')

# %%
basic.model_training_selection(x, y, 'SatLiquidVolume_'+compound, times_to_interpolate = 4)
# Out:
# [INFO] Linear Regression cross validation MAE: 0.0018
# [INFO] Linear Regression holdout set MAE: 0.0019
# [INFO] Linear Regression holdout set RMSE: 0.0034
# [INFO] Linear Regression holdout set R2: 0.8668
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.0002
# [INFO] Decision Tree Regressor holdout set MAE: 0.0002
# [INFO] Decision Tree Regressor holdout set RMSE: 0.0004
# [INFO] Decision Tree Regressor holdout set R2: 0.9984
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatLiquidVolume_ammonia

# %% [markdown]
# ## 3. Saturated Liquid Specific Enthalpy

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['h']]

# %%
# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_enthalpy')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_enthalpy')
# Out:
# Text(0, 0.5, 'specific_enthalpy')

# %%
basic.model_training_selection(x, y, 'SatLiquidEnthalpy_'+compound, times_to_interpolate = 4)
# Out:
# [INFO] Linear Regression cross validation MAE: 0.1887
# [INFO] Linear Regression holdout set MAE: 0.2006
# [INFO] Linear Regression holdout set RMSE: 0.3405
# [INFO] Linear Regression holdout set R2: 0.9958
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.0726
# [INFO] Decision Tree Regressor holdout set MAE: 0.0677
# [INFO] Decision Tree Regressor holdout set RMSE: 0.0765
# [INFO] Decision Tree Regressor holdout set R2: 0.9998
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatLiquidEnthalpy_ammonia

# %% [markdown]
# ## 4. Saturated Liquid Specific Entropy

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['s']]

# %%
# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_entropy')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_entropy')
# Out:
# Text(0, 0.5, 'specific_entropy')

# %%
basic.model_training_selection(x, y, 'SatLiquidEntropy_'+compound, times_to_interpolate = 4)
# Out:
# [INFO] Linear Regression cross validation MAE: 0.0008
# [INFO] Linear Regression holdout set MAE: 0.0009
# [INFO] Linear Regression holdout set RMSE: 0.0012
# [INFO] Linear Regression holdout set R2: 0.9953
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.0002
# [INFO] Decision Tree Regressor holdout set MAE: 0.0002
# [INFO] Decision Tree Regressor holdout set RMSE: 0.0002
# [INFO] Decision Tree Regressor holdout set R2: 0.9998
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatLiquidEntropy_ammonia

# %% [markdown]
# ## 5. Saturated Vapor Specific Volume

# %%
# import data
data = basic.load_filter_data(vapor_fraction = 1, 
                              fluid_code = FLUID_CODE, 
                              complete_filepath = os.path.join(SATURATION_DATA_FILEPATH, SATURATION_FILENAME))

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['v']]

# %%
# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_volume')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_volume')
# Out:
# Text(0, 0.5, 'specific_volume')

# %%
basic.model_training_selection(x, y, 'SatVaporVolume_' + compound, times_to_interpolate = 6)
# Out:
# [INFO] Linear Regression cross validation MAE: 26.8215
# [INFO] Linear Regression holdout set MAE: 24.0698
# [INFO] Linear Regression holdout set RMSE: 31.3835
# [INFO] Linear Regression holdout set R2: 0.5862
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.2196
# [INFO] Decision Tree Regressor holdout set MAE: 0.1761
# [INFO] Decision Tree Regressor holdout set RMSE: 0.4765
# [INFO] Decision Tree Regressor holdout set R2: 0.9999
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatVaporVolume_ammonia

# %% [markdown]
# ## 6. Saturated Vapor Specific Enthalpy

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['h']]

# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_enthalpy')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_enthalpy')
# Out:
# Text(0, 0.5, 'specific_enthalpy')

# %%
basic.model_training_selection(x, y, 'SatVaporEnthalpy_' + compound, times_to_interpolate = 6)
# Out:
# [INFO] Linear Regression cross validation MAE: 0.2179
# [INFO] Linear Regression holdout set MAE: 0.2184
# [INFO] Linear Regression holdout set RMSE: 0.3277
# [INFO] Linear Regression holdout set R2: 0.9126
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.0076
# [INFO] Decision Tree Regressor holdout set MAE: 0.0063
# [INFO] Decision Tree Regressor holdout set RMSE: 0.0113
# [INFO] Decision Tree Regressor holdout set R2: 0.9999
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatVaporEnthalpy_ammonia

# %% [markdown]
# ## 7. Saturated Vapor Specific Entropy

# %%
# select predictors and target
x = data[['t', 'p']]
y = data[['s']]

# explore correlations between predictors and target
fig = plt.figure(figsize = (14,7))
ax1 = fig.add_subplot(1,2,1)
plt.plot(x['t'], y, 'ko')
plt.xlabel('temperature')
plt.ylabel('specific_entropy')

ax2 = fig.add_subplot(1,2,2)
plt.plot(x['p'], y, 'ko')
plt.xlabel('pressure')
plt.ylabel('specific_entropy')
# Out:
# Text(0, 0.5, 'specific_entropy')

# %%
basic.model_training_selection(x, y, 'SatVaporEntropy_' + compound, times_to_interpolate = 6)
# Out:
# [INFO] Linear Regression cross validation MAE: 0.0017
# [INFO] Linear Regression holdout set MAE: 0.0016
# [INFO] Linear Regression holdout set RMSE: 0.0019
# [INFO] Linear Regression holdout set R2: 0.9831
# -------------------------------------------------------------------------------------------------
# [INFO] Decision Tree Regressor cross validation MAE: 0.0001
# [INFO] Decision Tree Regressor holdout set MAE: 0.0000
# [INFO] Decision Tree Regressor holdout set RMSE: 0.0001
# [INFO] Decision Tree Regressor holdout set R2: 1.0000
# -------------------------------------------------------------------------------------------------
# [INFO] Saving decisiontreeregressor_SatVaporEntropy_ammonia

# %% [markdown]
# ## 8. Saturation Property Models Validation
#
# <br>
#
# ### 8.1. Specific Volume

# %%
data1 = basic.load_filter_data(vapor_fraction = 0, 
                              fluid_code = FLUID_CODE, 
                              complete_filepath = os.path.join(SATURATION_DATA_FILEPATH, SATURATION_FILENAME))
data2 = basic.load_filter_data(vapor_fraction = 1, 
                              fluid_code = FLUID_CODE, 
                              complete_filepath = os.path.join(SATURATION_DATA_FILEPATH, SATURATION_FILENAME))
data = pd.concat([data1, data2])

# %%
validation.saturation_properties(data, FLUID_CODE, 'v')

# %% [markdown]
# ### 8.2. Specific Enthalpy

# %%
validation.saturation_properties(data, FLUID_CODE, 'h')

# %% [markdown]
# ### 8.3. Specific Entropy

# %%
validation.saturation_properties(data, FLUID_CODE, 's')
